# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# data load 

df = pd.read_csv(r"C:\Users\HP\Desktop\Cybrom work\Projects\Education Research Student Performance\Data\student-mat-pass-or-fail.csv")
df
# Out:
#      school  sex  age  address  famsize  Pstatus  Medu  Fedu  traveltime  \
# 0         1    1   18        1        0        0     4     4           2
# 1         1    1   17        1        0        1     1     1           1
# 2         1    1   15        1        1        1     1     1           1
# 3         1    1   15        1        0        1     4     2           1
# 4         1    1   16        1        0        1     3     3           1
# ..      ...  ...  ...      ...      ...      ...   ...   ...         ...
# 390       0    0   20        1        1        0     2     2           1
# 391       0    0   17        1        1        1     3     1           2
# 392       0    0   21        0        0        1     1     1           1
# 393       0    0   18        0        1        1     3     2           3
# 394       0    0   19        1        1        1     1     1           1
#
#      studytime  ...  freetime  goout  Dalc  Walc  health  absences  G1  G2  \
# ...

# %%
df.shape
# Out:
# (395, 30)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 30 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    int64
#  1   sex         395 non-null    int64
#  2   age         395 non-null    int64
#  3   address     395 non-null    int64
#  4   famsize     395 non-null    int64
#  5   Pstatus     395 non-null    int64
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   traveltime  395 non-null    int64
#  9   studytime   395 non-null    int64
#  10  failures    395 non-null    int64
#  11  schoolsup   395 non-null    int64
#  12  famsup      395 non-null    int64
#  13  paid        395 non-null    int64
#  14  activities  395 non-null    int64
#  15  nursery     395 non-null    int64
#  16  higher      395 non-null    int64
#  17  internet    395 non-null    int64
#  18  romantic    395 non-null    int64
# ...

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'traveltime', 'studytime', 'failures', 'schoolsup', 'famsup', 'paid',
#        'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel',
#        'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2',
#        'G3', 'pass'],
#       dtype='object')

# %% [raw]
# The dataset contains the student academic and behavioral data , making it perfect to do
# analyses on how the Study Habit gives impact on Academic Performance.

# %% [raw]
# I will select the dependent variable and the indrpendent variable in this

# %% [raw]
# Dependent variable:
#
#  -- G3
#
# The final exam score (G3) was selected as the dependent variable.
# Study time, absences, past failures, internet access, and previous exam scores (G1 and G2) were used as independent variables.

# %% [raw]
# Independent Variables (Predictors)
#
# These are the factors that influence the dependent variable:
#  -- studytime
#  -- failures
#  -- internet
#  -- absences
#  -- G1
#  -- G2

# %%
# drop the coloumn which will be no use 

df = df.drop(columns = ['school', 'sex', 'age', 'address', 'famsize', 'Pstatus',
    'Medu', 'Fedu', 'traveltime', 'schoolsup', 'famsup',
    'paid', 'activities', 'nursery', 'higher', 'romantic',
    'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health', 'pass'])
df.head()
# Out:
#    studytime  failures  internet  absences  G1  G2  G3
# 0          2         0         0         6   5   6   6
# 1          2         0         1         4   5   5   6
# 2          2         3         1        10   7   8  10
# 3          3         0         1         2  15  14  15
# 4          2         0         0         4   6  10  10

# %%
#  rename the columns for better understanding

df = df.rename(columns = {"studytime" : "study_hours", 
                           "failures" : "past_failures",
                           "G1" : "first_period_score",
                           "G2" : "second_period_score",
                           "G3" : "final_exam_score"})
df
# Out:
#      study_hours  past_failures  internet  absences  first_period_score  \
# 0              2              0         0         6                   5
# 1              2              0         1         4                   5
# 2              2              3         1        10                   7
# 3              3              0         1         2                  15
# 4              2              0         0         4                   6
# ..           ...            ...       ...       ...                 ...
# 390            2              2         0        11                   9
# 391            1              0         1         3                  14
# 392            1              3         0         3                  10
# 393            1              0         1         0                  11
# 394            1              0         1         5                   8
#
#      second_period_score  final_exam_score
# 0                      6                 6
# ...

# %%
df["internet"].value_counts()

# The internet access variable was already binary encoded in the dataset and did not require additional transformation.
# Out:
# internet
# 1    329
# 0     66
# Name: count, dtype: int64

# %%
# Data Validation 

df.isnull().sum()
# Out:
# study_hours            0
# past_failures          0
# internet               0
# absences               0
# first_period_score     0
# second_period_score    0
# final_exam_score       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 11

# %%
df.describe()
# Out:
#        study_hours  past_failures    internet    absences  first_period_score  \
# count   395.000000     395.000000  395.000000  395.000000          395.000000
# mean      2.035443       0.334177    0.832911    5.708861           10.908861
# std       0.839240       0.743651    0.373528    8.003096            3.319195
# min       1.000000       0.000000    0.000000    0.000000            3.000000
# 25%       1.000000       0.000000    1.000000    0.000000            8.000000
# 50%       2.000000       0.000000    1.000000    4.000000           11.000000
# 75%       2.000000       0.000000    1.000000    8.000000           13.000000
# max       4.000000       3.000000    1.000000   75.000000           19.000000
#
#        second_period_score  final_exam_score
# count           395.000000        395.000000
# mean             10.713924         10.415190
# std               3.761505          4.581443
# min               0.000000          0.000000
# ...

# %% [raw]
# The dataset was validated to ensure completeness, uniqueness, and logical value ranges.

# %%
# to save the cleaned file we will do

df.to_csv(
    r"C:\Users\HP\Desktop\Cybrom work\Projects\Education Research Student Performance\Data\student_mat_cleaned.csv",
    index=False
)

# %%
# to check
import os
os.path.exists("../data/student_mat_cleaned.csv")
# Out:
# True

# %% [raw]
# The cleaned dataset was saved locally to ensure reproducibility and consistency across analysis stages.
