# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\HP\Desktop\Cybrom work\Projects\Education Research Student Performance\Data\student_mat_cleaned.csv")
df.head()
# Out:
#    study_hours  past_failures  internet  absences  first_period_score  \
# 0            2              0         0         6                   5
# 1            2              0         1         4                   5
# 2            2              3         1        10                   7
# 3            3              0         1         2                  15
# 4            2              0         0         4                   6
#
#    second_period_score  final_exam_score
# 0                    6                 6
# 1                    5                 6
# 2                    8                10
# 3                   14                15
# 4                   10                10

# %% [raw]
# Now we will perform the correlation analysis by which we observe the relationship of the variables
# correlation analysis only can be performed on numerical data
#
# In my dataset all the columns contain the numeric value but still we check for the

# %%
# we will check for the numeric column and store in a variable

numeric_df = df.select_dtypes(include='number')
numeric_df.columns
# Out:
# Index(['study_hours', 'past_failures', 'internet', 'absences',
#        'first_period_score', 'second_period_score', 'final_exam_score'],
#       dtype='object')

# %%
# Now i will perform correlation matrix

corr_matrix = numeric_df.corr()
corr_matrix
# Out:
#                      study_hours  past_failures  internet  absences  \
# study_hours             1.000000      -0.173563  0.059422 -0.062700
# past_failures          -0.173563       1.000000 -0.063451  0.063726
# internet                0.059422      -0.063451  1.000000  0.101701
# absences               -0.062700       0.063726  0.101701  1.000000
# first_period_score      0.160612      -0.354718  0.071619 -0.031003
# second_period_score     0.135880      -0.355896  0.119439 -0.031777
# final_exam_score        0.097820      -0.360415  0.098483  0.034247
#
#                      first_period_score  second_period_score  final_exam_score
# study_hours                    0.160612             0.135880          0.097820
# past_failures                 -0.354718            -0.355896         -0.360415
# internet                       0.071619             0.119439          0.098483
# absences                      -0.031003            -0.031777          0.034247
# first_period_score             1.000000             0.852118          0.801468
# second_period_score            0.852118             1.000000          0.904868
# final_exam_score               0.801468             0.904868          1.000000

# %% [raw]
# Now we visualize this correlation matrix with heat map which will help to understand the relationship it is very important for
# to understant the relationship with the variables

# %%
# heat map

plt.figure(figsize=(10,6))
sns.heatmap(corr_matrix,cmap='viridis')
# Out:
# <Axes: >
